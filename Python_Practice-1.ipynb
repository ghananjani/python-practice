# %% [markdown]
# # Python

# %% [markdown]
# # New Section

# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
#shift plus enter for shortcut run.
#data needs to be stored in the database on the python database
#python supports scripting, without oops, hence python is flexible.

#VARIABLE....
# eg:  a=10, we are making a variable a which has a value stored in it which is 10. We can score complex
# datatypes in this variable.

#DONT FORGET TO EXECUTE THE VARIABLES.

# %%
a=10

# %%
b=5

# %%
a+b
# Out:
# 15

# %%
a
# Out:
# 10

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7d157d7c000a> in <cell line: 1>()
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
#PYTHON IS CASE SENSITIVE, Variable can be any collection of word.
#everything startes from variable declaration

# %%
sudh = 10

# %%
a+sudh
# Out:
# 20

# %%
type(a)
# tells us about the datatype
#integer-type of data, whole number
#float- decimal wala number
# Out:
# int

# %%
b=2.09

# %%
type(b)
# Out:
# float

# %%
c=45.243521

# %%
type(c)
# Out:
# float

# %%
d="sudhanshu"
# for string use double quotes or single quotes

# %%
type(d)
# Out:
# str

# %%
e='this is my first code'

# %%
type(e)
# Out:
# str

# %%
n = True
# True or False, t and f capital, boolean
# true is 1 and false is 0

# %%
type(n)
# Out:
# bool

# %%
m = False

# %%
m+n
# m= 0, n=1 , hence n+m=1
# Out:
# 1

# %%
True * True
# 1 * 1
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True/False
# in python, 1/0, anything divided by 0 will always give an error,
# in numpy, infinity will be the result, it will be valid there.
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-32-f64d1295bbce> in <cell line: 1>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
v = 5+8j
# generally in math, where we used i, we use j in python.

# %%
type(v)
#shift + tab for knowing the need of the function.
# Out:
# complex

# %%
v.real
# variable. real, real value of v will be given to you.
# Out:
# 5.0

# %%
a= 5+7j

# %%
a
#variable updation works in python.
# Out:
# (5+7j)

# %%
v.imag
#imaginary part of v, v was 5+8j hence imag is 8 here.
# Out:
# 8.0

# %%
print("my name is ghananjani")
#helps to print in console.
# Out:
# my name is ghananjani

# %%
print("v")
# Out:
# v

# %%
print(v)
# Out:
# (5+8j)

# %%
s+"pwskills"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a59d68db994e> in <cell line: 1>()
# ----> 1 s+"pwskills"
#
# NameError: name 's' is not defined

# %%
s="pwskills"

# %%
type(s)
# Out:
# str

# %%
s[0]
#forward direction
# Out:
# 'p'

# %%
s[5]
#forward direction- from 0 to x number from first letter.
# backward direction indexing starts from -1 from the backward side
# Out:
# 'l'

# %%
s[-1]
# Out:
# 's'

# %%
s[0:3]
# SLICING...... (based on indexing)
#0-START FROM
#3- END IT, 3 not included.
# Out:
# 'pws'

# %%
s[0:8:2]
#jumping parameter. After you regular number you write the criterion for jumping
#you can leave the places for ending and starting empty
# Out:
# 'psil'

# %%
s[::2]
# Out:
# 'psil'

# %%
s[2::2]
# Out:
# 'sil'

# %%
s[2::0]
# slice step cannot be 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a9a52abc7999> in <cell line: 1>()
# ----> 1 s[2::0]
#
# ValueError: slice step cannot be zero

# %%
s[::-1]
#backward
# Out:
# 'sllikswp'

# %%
s[2:7:-1]
# read as start from 2, go till 7, jump -1
# why empty? - starting point is 2, we are going till 7, and -1 we are doing, hence we are rising a conflict
#because direction is different.
# Out:
# ''

# %%
s[8:0]
#peeche jaa rhe haiiiiii, +1 hoga iske hisaab se jump, -1 hota toh ho jata
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'slliksw'

# %%
s[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-deb1ec67c953> in <cell line: 1>()
# ----> 1 s[90]
#
# IndexError: string index out of range

# %%
s[:-90:-1]
#in slicing, you are giving range, index available nhi hoga toh bhi error nhi aayega, UPPER BOUND DOESNOT MATTER
# Out:
# 'sllikswp'

# %%
c=200

# %%
s1 = "this is my string class"
#string has many inbuilt functions which can be used.

# %%
#FUNCTIONS IN STRINGS!!!!!!!!!!
len(s1)
# len tells us about the length of the string
# Out:
# 23

# %%
#to find if s is available in string
s1.find('s')
# gives us the output of where s is available first while going in forward direction
# Out:
# 3

# %%
s1.find('is')
#you can find string also
# Out:
# 2

# %%
s1.find('iS')
#agar kuch nhi mil rha hai python ko toh woh -1 de dega answer. error nhi milta
# Out:
# -1

# %%
s1.find("is")
#select tab after clicking on the cell toh milega bahut sara functions tumko
# Out:
# 2

# %%
s1.count('s')
#bta dega ki s kitni baar aaya hai
# Out:
# 5

# %%
s1.count('is')
# Out:
# 2

# %%
s1.count('z')
# Out:
# 0

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.UPPER
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-ae9e21aa385e> in <cell line: 1>()
# ----> 1 s1.UPPER
#
# AttributeError: 'str' object has no attribute 'UPPER'

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s1.lower()
# Out:
# 'this is my string class'

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.title()
# Out:
# 'This Is My String Class'

# %%
s1.capitalized()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-4f403bd12f8e> in <cell line: 1>()
# ----> 1 s1.capitalized()
#
# AttributeError: 'str' object has no attribute 'capitalized'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s
# Out:
# 'pwskills'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-2a618fcb9031> in <cell line: 1>()
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+sudh
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-48ef37a7b341> in <cell line: 1>()
# ----> 1 s+sudh
#
# TypeError: can only concatenate str (not "int") to str

# %%
s + "sudh"
# Out:
# 'pwskillssudh'

# %%
s + "12"
#concatenation ho rha hai yaha
# Out:
# 'pwskills12'

# %%
s*3
# Out:
# 'pwskillspwskillspwskills'

# %%
s/4
#division is not valid for string, + aur * chlta hai bas. power vgera bhi nhi hota
#int mei hota hai sab
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-2166911eb140> in <cell line: 1>()
# ----> 1 s/4
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
'don't do copy and paste in my class'
#andar quote use hogya, error aayega
# Out:
#   File "<ipython-input-87-a837ea90949d>", line 1
#     'don't do copy and paste in my class'
#                                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"don't do cupy paste"
#seperate the quotes
## use this
# for zada lines of comments
"""ahwbfj
cahbhjsf
anjsba"""
# Out:
# "don't do cupy paste"

# %%
'''premitive datatype: int,float.str,etc
other data types: list, tupple,set.dictionary etc
there are various provisions. '''
l=[1,345,45,'sudh',True,345.678]
#yeh sab yaha store hogya list , jitna chaho utna daal skte ho
#square bracket mei rkhna hai
#same way mei data nikaal skte ko with list functions, jese string mei nikaal rhe the

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[6]
#indexinggggg
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-cb842cca7e42> in <cell line: 1>()
# ----> 1 l[6]
#
# IndexError: list index out of range

# %%
l[5]
# Out:
# 345.678

# %%
l[0:4]
#same list jese
# Out:
# [1, 345, 45, 'sudh']

# %%
s="pwskills"

# %%
l+s
#nhi chalega
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c62842885d3f> in <cell line: 1>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)
#jab string ko list mei krte ho toh list string ko tod deta hai aur individually store krta h
# Out:
# ['p', 'w', 's', 'k', 'i', 'l', 'l', 's']

# %%
l
#su ko nikaal kar dikhao
# Out:
# [1, 345, 45, 'sudh', True, 345.678]

# %%
l[3]
#pehle sudh nikaal lo
# Out:
# 'sudh'

# %%
#ab sudh mei se su nikaalna h by slicing

# %%
l[3][0:2]
# Out:
# 'su'

# %%
l+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-19ae9a22dca0> in <cell line: 1>()
# ----> 1 l+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l.append(5)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, 345.678, 5]

# %%
l1=[3,4,5]

# %%
l1+l
#list mei list bhi append kr skte hai
# Out:
# [3, 4, 5, 1, 345, 45, 'sudh', True, 345.678, 5]

# %%
l1*3
#string wala function
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
s
# Out:
# 'pwskills'

# %%
l1
# Out:
# [3, 4, 5]

# %%
l.append(l1)
#list ke andar list store kr skte hai

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, 345.678, 5, [3, 4, 5]]

# %%
l[-1][1]
#list ke andar ke list ka data nikaalna
# Out:
# 4

# %%
l.extend("sudh")
#after breaking add ho rha h , integer nhi daal skte kyuki indexing nhi hota toh extend
#nhi ho pata, isliye sirf iterable type dats extend hota hai

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, 345.678, 5, [3, 4, 5], 's', 'u', 'd', 'h']

# %%
l.extend([3,4,5])
#list daal kar hogya

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, 345.678, 5, [3, 4, 5], 's', 'u', 'd', 'h', 3, 4, 5]

# %%
l.extend(456)
error aaya
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-6ae0219a10c8> in <cell line: 1>()
# ----> 1 l.extend(456)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("456")
#quottes mei daala toh string ban gya toh hogya

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  345.678,
#  5,
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  '4',
#  '5',
#  '6']

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1.insert(1,"sudh")
#particular index par data daal deta hai
#pehla kaha, dusra kya

# %%
l1
# Out:
# [3, 'sudh', 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], 'sudh', 4, 5]

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], 'sudh', 4, 45, 5]

# %%
l1.pop(1)
#remove krta hai
# Out:
# 'sudh'

# %%
l1
# Out:
# [3, [2, 3, 4], 'sudh', 4, 45, 5]

# %%
l1.remove(3)
#jo value nikaalna h woh nikaal dega

# %%
l1
# Out:
# [[2, 3, 4], 'sudh', 4, 45, 5]

# %%
#l1. likh ke shift daba do to check the function u can use
l1[2]
# Out:
# 4

# %%
l1=[45,'sudh',[2,3,4],4]

# %%
l1[2].remove(3)
#list ke andar ka koi nikaalne ke liye

# %%
l1
# Out:
# [45, 'sudh', [2, 4], 4]

# %%
l1.remove(4)

# %%
l1
# Out:
# [45, 'sudh', [2, 4]]

# %%
l1.reverse()

# %%
l1
# Out:
# [[2, 4], 'sudh', 45]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b8f5f256bbcf> in <cell line: 1>()
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'list'

# %%
l2=[3,72,48,192,466,9,2]

# %%
l2.sort()
#ascending order, sirf integers mei kaam hoga, string mei aur integer mix mei nhi

# %%
l2
# Out:
# [2, 3, 9, 48, 72, 192, 466]

# %%
l4=["sudh", "kumar","pwskills", "data science"]

# %%
l4.sort()

# %%
l4
# Out:
# ['data science', 'kumar', 'pwskills', 'sudh']

# %%
l4.sort(reverse=True)
#descind mei hogya

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
l4.index("sudh")
# Out:
# 0

# %%
l4.count("sudh")
# Out:
# 1

# %%
s="sudh"

# %%
l5=[3,4,5,6]

# %%
s[0] = 'a'
#'str' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-640fc9a3a8b2> in <cell line: 1>()
# ----> 1 s[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0] = 30
# 3 ki jagah 30 daal do
#string mei nhi hota, list mei ho jata hai

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
s
# Out:
# 'sudh'

# %%
s.replace('s', 'a')
# Out:
# 'audh'

# %%
s
#original s nhi badla, par naya location ban gya, reassign ho jata hai bas
# Out:
# 'sudh'

# %%
t = (2,3,4,5,"sudh", 45.46, False, 45+457j, [3,4,5])
#tuple () bracket mei hota hai, list [ ] mei hota hai

# %%
t
''' tuple bhi list jes collection hai, sab data rakh skte ho in tuple also
tuple use kyu krte hai lekin fir?
difference: list is mutable, tuple is not mutable
# Out:
# (2, 3, 4, 5, 'sudh', 45.46, False, (45+457j), [3, 4, 5])

# %%
type(t)
#same
# Out:
# tuple

# %%
len(t)
#same
# Out:
# 9

# %%
t[0]
#same
# Out:
# 2

# %%
t[-1]
#same
# Out:
# [3, 4, 5]

# %%
t[::-1]
#same
# Out:
# ([3, 4, 5], (45+457j), False, 45.46, 'sudh', 5, 4, 3, 2)

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
l4[0] = 23424
#list mei allowed hai

# %%
l4
# Out:
# [23424, 'pwskills', 'kumar', 'data science']

# %%
t[0] = "sudh"
#tuple allow nhi krta
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-2f95be8375a0> in <cell line: 1>()
# ----> 1 t[0] = "sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(50)
# Out:
# 0

# %%
t.index(False)
# Out:
# 6

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.46, False, (45+457j), [3, 4, 5])

# %%
#SET
s1 = {}
#empty set is dictionary

# %%
type(s1)
# Out:
# dict

# %%
s2 = {2,3,4,55,6}

# %%
type(s2)
#with data wala set is set
#set mei alag se list nhi rakh skte, tuple le leta hai
#sirf immutable wale rkh skte ho
# Out:
# set

# %%
s3 = {324, 456, "sudh", 45+6j, 43.87, (3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+6j), 324, 43.87, 456, 'sudh'}

# %%
#use of set?
s4={2,3,4,5,6,3,6,43,2,4,7,4,24,5,4,2,4,6,34,6,3,4,4,5,4,5}
#repetitive elements wala set
#tumko unique wale elemts nikaal kr dena hai

# %%
s4
#removes all duplicates:sets
# Out:
# {2, 3, 4, 5, 6, 7, 24, 34, 43}

# %%
l6= [2,2,3,4,5,6,3,6,43,2,4,7,4,24,5,4,2,4,6,34,6,3,4,4,5,4,5, "sudh", "sudh"]

# %%
l6 = list(set(l6))

# %%
l6
# Out:
# [2, 3, 4, 5, 6, 7, 34, 43, 'sudh', 24]

# %%
#SET MEI SLICING, INDEXING NHI KAAM KARTA
s4.add(4)
#set mei add, remove, chlta hai, data ko, not indexing

# %%
s4
# Out:
# {2, 3, 4, 5, 6, 7, 24, 34, 43}

# %%
d={}
#without key value pair it is set, with them it is dict n if empty then dict

# %%
type(d)
# Out:
# dict

# %%
d1 = {'key' : "sudh" }
##key should be unique
#anything can be key value type

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2 = { 'name' : "sudhanshu" , "email" : "@gmail.com", "number" : 6547767}

# %%
d2
# Out:
# {'name': 'sudhanshu', 'email': '@gmail.com', 'number': 6547767}

# %%
d3 = {263: "sudh", True : 5765765}
#numeric aur string values le skte ho, boolean bhi allowed hai
#special case characters are not allowed eg _, @ alag se not allowed but quotes ke andar allowed h

# %%
d3
# Out:
# {263: 'sudh', True: 5765765}

# %%
d3[263]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 5765765

# %%
d3[1]
#yaha 1 is true
# Out:
# 5765765

# %%
d3[2]
#yeh nhi hua
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-51238f87b54e> in <cell line: 1>()
# ----> 1 d3[2]
#
# KeyError: 2

# %%
d5 = {'course' : ['math', 'english'  , 'science', 'sst'] , 'by': 'pwskilks' }

# %%
d5
# Out:
# {'course': ['math', 'english', 'science', 'sst'], 'by': 'pwskilks'}

# %%
d5['course']
# Out:
# ['math', 'english', 'science', 'sst']

# %%
d5['course'][2]
# Out:
# 'science'

# %%
d6 = {"number": [2,3884,373,28,30], "assignments" : (1,2,3,4,5,6), "launch_date" : {23/9/23} }

# %%
d6
# Out:
# {'number': [2, 3884, 373, 28, 30],
#  'assignments': (1, 2, 3, 4, 5, 6),
#  'launch_date': {0.1111111111111111}}

# %%
d6["launch_date"]
# Out:
# {0.1111111111111111}

# %%
d6.keys()
#give key values
# Out:
# dict_keys(['number', 'assignments', 'launch_date'])

# %%
list(d6.keys())
# Out:
# ['number', 'assignments', 'launch_date']

# %%
list(d6.values())
# Out:
# [[2, 3884, 373, 28, 30], (1, 2, 3, 4, 5, 6), {0.1111111111111111}]

# %%
d6.items()
#key value pairs
# Out:
# dict_items([('number', [2, 3884, 373, 28, 30]), ('assignments', (1, 2, 3, 4, 5, 6)), ('launch_date', {0.1111111111111111})])

# %%
list(d6.items())
# Out:
# [('number', [2, 3884, 373, 28, 30]),
#  ('assignments', (1, 2, 3, 4, 5, 6)),
#  ('launch_date', {0.1111111111111111})]

# %%
d6.pop("number")
#removes particular which u ask to be removed
# Out:
# [2, 3884, 373, 28, 30]

# %%
d6
# Out:
# {'assignments': (1, 2, 3, 4, 5, 6), 'launch_date': {0.1111111111111111}}

# %%
d6.pop("assignments")
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
d6
# Out:
# {'launch_date': {0.1111111111111111}}

# %%
#if else statements
marks = 65

if marks >=80:
  print("you will be a part of A0 Batch")
  elif  marks>= 60 and marks<80:
print ("you are part of A1 batch")
elif  marks>= 40 and marks<60:
  print("you are part of A2 batch")
else :
  print("you are part of A3 batch")
# Out:
#   File "<ipython-input-8-7b5028506930>", line 7
#     print ("you are part of A1 batch")
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 6

# %%
marks = 65

if marks >=80:
  print("you will be a part of A0 Batch")
elif marks>= 60 and marks<80:
print ("you are part of A1 batch")
elif marks>= 40 and marks<60:
  print("you are part of A2 batch")
else :
  print("you are part of A3 batch")

  '''The error in the code lies in the indentation of the second elif statement.
   In Python, indentation is crucial to define the structure and hierarchy of the code.
   In the provided code, the second elif statement lacks proper indentation,
   which leads to a syntax error.

   Indentation in Python is a whitespace-based syntax element used to define the structure,
 hierarchy, and grouping of code blocks. It serves as a way to visually represent
 the scope and nesting of statements within conditional statements, loops, functions, and classes.

In Python, indentation is typically done using spaces or tabs (preferably four spaces).
 Consistent and proper indentation is crucial because it determines which statements belong to a particular block of code. Unlike other programming languages that use curly braces or keywords to denote code blocks, Python uses indentation to delimit blocks.

Here's an example to illustrate the use of indentation in Python:

```python
if condition:
    # Indented block of code
    statement_1
    statement_2
    statement_3
else:
    # Another indented block of code
    statement_4
    statement_5
```

In the above code snippet, the statements within the `if` and `else` blocks are indented using four spaces, indicating that they belong to their respective blocks. The indentation helps Python interpret the code correctly and determine the flow of execution.

It's important to note that consistent indentation is necessary for Python code to be valid and executable. Mixing tabs and spaces or using inconsistent indentation can result in syntax errors.
# Out:
#   File "<ipython-input-6-10f709233878>", line 6
#     print ("you are part of A1 batch")
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 5

# %%
marks = 65

if marks >= 80:
  print("You will be a part of A0 Batch")
elif marks >= 60 and marks < 80:
  print("You are part of A1 Batch")
elif marks >= 40 and marks < 60:
  print("You are part of A2 Batch")
else:
  print("You are part of A3 Batch")
# Out:
# You are part of A1 Batch

# %%
marks = input("enter your marks:")
#problem with input is: yeh convert kr deta hai your input into string.

if marks >= 80:
  print("You will be a part of A0 Batch")
elif marks >= 60 and marks < 80:
  print("You are part of A1 Batch")
elif marks >= 40 and marks < 60:
  print("You are part of A2 Batch")
else:
  print("You are part of A3 Batch")

# %%
marks = int(input("enter your marks:"))

if marks >= 80:
  print("You will be a part of A0 Batch")
elif marks >= 60 and marks < 80:
  print("You are part of A1 Batch")
elif marks >= 40 and marks < 60:
  print("You are part of A2 Batch")
else:
  print("You are part of A3 Batch")
# Out:
# enter your marks:44
# You are part of A2 Batch

# %%
marks = int(input("enter your marks:"))

if marks >= 80:
  print("You will be a part of A0 Batch")
elif marks >= 60 and marks < 80:
  print("You are part of A1 Batch")
elif marks >= 40 and marks < 60:
  print("You are part of A2 Batch")
else:
  print("You are part of A3 Batch")



  #LESSON: PYTHON BAHUT ZADA CASE SENSITIVE HAI, SPACE BHI NHI JAMTA

# %%
price = int(input("enter price:"))
if price > 1000:
  print ("i will not purchase")
else :
  print("ok bye")

# %%
l = [1,2,3,3,4,5,6,7,8]
#add 1 to each element in list

# %%
l[0]+1

# %%
l1.append(l[0]+1)

# %%
l1
