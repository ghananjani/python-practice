# %%
# Mathematical Functions
x = sqrt(25)

'''
error
because u have to ask for the math functions
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dc4468502428> in <cell line: 2>()
#       1 # Mathematical Functions
# ----> 2 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
x = math.sqrt(25)

# %%
x
# Out:
# 5.0

# %%
# floor function
'''
eg u have 2.5, u want to have integer only
so if u have 2.5: 3
2.4:3
so in floor function: u get round off
in floor function u will get the lower value always
eg : 2.9 will also give u 2 and 2.3 will also give u 2

similarly ceil will give u higher value'''

print(math.floor(2.3))
# Out:
# 2

# %%
print(math.floor(2.9))
# Out:
# 2

# %%
print(math.ceil(2.4))
# Out:
# 3

# %%
# power function
#substitution for 3**2

print(math.pow(3,2))
# Out:
# 9.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
import math as m

# %%
m.sqrt(25)
# Out:
# 5.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pow

# %%
pow(4,5)
# Out:
# 1024.0

# %%
sqrt(100)
# Out:
# 10.0

# %%
help('math')
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
# ...

# %%
#user input

x = input()
y = input()
z = x+y
print(z)
# Out:
# 3
# 4
# 34

# %%
#user input

3
# input will always by default give u string values
# Out:
# enter number 1 2
# enter number 2 3
# 23

# %%
x = int(input("enter number 1 "))
y = int(input("enter number 2 "))
z = x+y
print(z)
# Out:
# enter number 1 3
# enter number 2 4
# 7

# %%
ch = input('enter a char ')
print(ch)
# Out:
# enter a chargh
# gh

# %%
ch = input('enter a char ') [0]
print(ch)
# u assign ch to whole gha, but print will be only 0
# Out:
# enter a char gha
# g

# %%
# agrv: argument values
import sys
x = sys.argv[1]
y = sys.argv[2]
z = x + y
print(z)
# Out:
# -f/root/.local/share/jupyter/runtime/kernel-ac2342a8-3bf8-493d-b498-c1815b7720ed.json

# %%
# if elif else statement

if True:
  print("i am right")
# Out:
# i am right

# %%
if False:
  print("i am right")
print("bye")
# hence it is important to use indentation
# Out:
# bye

# %%
if True:
  print("i am right")
print("bye")
# Out:
# i am right
# bye

# %%
if False:
  print("i am right")
  print("bye")

# %%
x = 3
r = x % 2

if r == 0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
x = 8
r = x%2

if r == 0:
  print("even")
  if x>5:
    print("good")
  else:
    print("not good")

else:
  print("odd")

print("bye")
# Out:
# even
# good
# bye

# %%
# if elif and else

x = 2

if x==1:
  print("one")

if x==2:
  print("two")


if x==3:
  print("three")

# here even after we get our output, the code will still execute all the other conditions
if x==4:
  print("four")
# Out:
# two

# %%
x = 2

if x==1:
  print("one")

  # if this is false only then elif condition will go

elif x==2:
  print("two")


elif x==3:
  print("three")


elif x==4:
  print("four")
# Out:
# two

# %%
x = 2

if x==1:
  print("one")

  # if this is false only then elif condition will go

elif x==2:
  print("two")


elif x==3:
  print("three")


elif x==4:
  print("four")

else:
  print("bye")
# Out:
# two

# %%
#while loop

i = 1 # initialisation

while i<=5: # condition
  print("hi")
  i = i+1 # increment/decrement
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
i = 1 # initialisation

while i>=1: # condition
  print("hi" , i)
  i = i-1 # increment/decrement
# Out:
# hi 1

# %%
i = 1
j = 1

while i<5:
  print("tanvi")
  while j<=4:
    print("bansal")
    j=j+1

    i = i+1
# Out:
# tanvi
# bansal
# bansal
# bansal
# bansal
